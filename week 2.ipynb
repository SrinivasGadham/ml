# %%
import pandas as pd

# %%
df=pd.read_csv("AKC Breed Info.csv", encoding='latin-1')
df
# Out:
#                     Breed height_low_inches height_high_inches weight_low_lbs  \
# 0                   Akita                26                 28             80
# 1      Anatolian Sheepdog                27                 29            100
# 2    Bernese Mountain Dog                23                 27             85
# 3              Bloodhound                24                 26             80
# 4                  Borzoi                26                 28             70
# ..                    ...               ...                ...            ...
# 145              Papillon                 8                 11              5
# 146            Pomeranian                12                 12              3
# 147            Poodle Toy                10                 10             10
# 148       Toy Fox Terrier                10                 10              4
# 149     Yorkshire Terrier                 8                  8              3
#
#     weight_high_lbs
# ...

# %%
print(df.shape)
# Out:
# (150, 5)

# %%
print(df.dtypes)
# Out:
# Breed                 object
# height_low_inches     object
# height_high_inches    object
# weight_low_lbs        object
# weight_high_lbs       object
# dtype: object

# %%
print(df.describe())
# Out:
#         Breed height_low_inches height_high_inches weight_low_lbs  \
# count     150               150                150            150
# unique    150                29                 30             49
# top     Akita                10                 27             45
# freq        1                14                 16             12
#
#        weight_high_lbs
# count              150
# unique              50
# top                 70
# freq                11

# %%
print(df.isna().sum())
# Out:
# Breed                 0
# height_low_inches     0
# height_high_inches    0
# weight_low_lbs        0
# weight_high_lbs       0
# dtype: int64

# %%
df=df.rename(columns={"Breed":"Breed_height"})
df
# Out:
#              Breed_height height_low_inches height_high_inches weight_low_lbs  \
# 0                   Akita                26                 28             80
# 1      Anatolian Sheepdog                27                 29            100
# 2    Bernese Mountain Dog                23                 27             85
# 3              Bloodhound                24                 26             80
# 4                  Borzoi                26                 28             70
# ..                    ...               ...                ...            ...
# 145              Papillon                 8                 11              5
# 146            Pomeranian                12                 12              3
# 147            Poodle Toy                10                 10             10
# 148       Toy Fox Terrier                10                 10              4
# 149     Yorkshire Terrier                 8                  8              3
#
#     weight_high_lbs
# ...

# %%
df1=df.to_string()
print(df1)
# Out:
#                            Breed_height height_low_inches height_high_inches weight_low_lbs weight_high_lbs
# 0                                 Akita                26                 28             80             120
# 1                    Anatolian Sheepdog                27                 29            100             150
# 2                  Bernese Mountain Dog                23                 27             85             110
# 3                            Bloodhound                24                 26             80             120
# 4                                Borzoi                26                 28             70             100
# 5                           Bullmastiff                25                 27            100             130
# 6                            Great Dane                32                 32            120             160
# 7                        Great Pyrenees                27                 32             95             120
# ...
